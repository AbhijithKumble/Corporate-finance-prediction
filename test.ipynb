# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from pathlib import Path
from datetime import datetime
import glob

# %%
df=pd.read_csv('data/other_data/pe_ratio.csv')

# %%
df.head()
# Out:
#             Company Name   Jun 2010   Sep 2010   Dec 2010   Mar 2011  \
# 0        20 Microns Ltd.   0.000000   0.000000   0.000000   0.000000
# 1    3B Blackbio Dx Ltd.  42.916667  18.205128  29.435484   0.000000
# 2       3I Infotech Ltd.  19.375000  18.564815  18.384615  13.476923
# 3          3M India Ltd.   0.000000   0.000000   0.000000   0.000000
# 4  3P Land Holdings Ltd.   0.000000   0.000000   0.000000   0.000000
#
#     Jun 2011   Sep 2011    Dec 2011  Mar 2012  Jun 2012  ...    Mar 2023  \
# 0   0.000000   0.000000    0.000000       0.0       0.0  ...   28.117424
# 1  60.319149  39.777778  112.142857       0.0      42.5  ...   60.072254
# 2  22.105263  10.436508    0.000000       0.0       0.0  ...    0.000000
# 3   0.000000   0.000000    0.000000       0.0       0.0  ...  190.989791
# 4   0.000000   0.000000    0.000000       0.0       0.0  ...  136.133333
#
#      Jun 2023    Sep 2023    Dec 2023    Mar 2024    Jun 2024   Sep 2024  \
# ...
